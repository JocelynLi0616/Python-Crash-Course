# %%
#Plotting a simple line graph

import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 24]
plt.plot(squares)
plt.show() #open the matplotlob viewer and display the plot

# %%
# Changing the Label Type and Graph Thickness

import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 24]
plt.plot(squares, linewidth =5)

#set chat title and label axes.
plt.title("Square Numbers", fontsize = 20)
plt.xlabel("Value", fontsize = 14)
plt.ylabel("Square of Value", fontsize = 14)

# set size of tick labels
plt.tick_params(axis = 'both', labelsize =14)

plt.show()

# %%
# Correcting the Plot 

import matplotlib.pyplot as plt

input = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 24]
plt.plot(input, squares, linewidth =5)

#set chat title and label axes.
plt.title("Square Numbers", fontsize = 20)
plt.xlabel("Value", fontsize = 14)
plt.ylabel("Square of Value", fontsize = 14)

# set size of tick labels
plt.tick_params(axis = 'both', labelsize =14)

plt.show()

# %%
# Scatter plot 
import matplotlib.pyplot as plt

plt.scatter(2, 4)
plt.show()

# %%
# Scatter plot 
import matplotlib.pyplot as plt

plt.scatter(2, 4, s=200)

# Set chart title and label axes
plt.title("Square Numbers", fontsize = 20)
plt.xlabel("Value", fontsize = 10)
plt.ylabel("Square of Value", fontsize = 10)

# Set size of tick labels 
plt.tick_params(axis = "both", which = "major", labelsize = 14)

plt.show()

# %%
# Plotting a Series of Points with scatter()
# edgecolor, and there is no edgecolor 

import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.scatter(x_values, y_values,  edgecolor='none', s = 100)

# Set chart title and label axes
plt.title("Square Numbers", fontsize = 20)
plt.xlabel("Value", fontsize = 10)
plt.ylabel("Square of Value", fontsize = 10)

# Set size of tick labels 
plt.tick_params(axis = "both", which = "major", labelsize = 14)

plt.show()

# %%
# Calculating Data Automatically 

import matplotlib.pyplot as plt

x_value = range(1,1100)
y_value = [x**2 for x in x_value]

plt.scatter(x_value, y_value, s=1)

# Set chart title and label axes
plt.title("Square Numbers", fontsize = 20)
plt.xlabel("Value", fontsize = 10)
plt.ylabel("Square of Value", fontsize = 10)

#The axis() function requires four values: the minimum and maximum values for the x-axis and the y-axis. 
plt.axis([0, 1100, 0, 1100000])

plt.show()

# %%
# defining custom colors c = 'red' by using RGB color model 

import matplotlib.pyplot as plt

x_value = range(1,1100)
y_value = [x**2 for x in x_value]

plt.scatter(x_value, y_value, s=1, c = (0.2, 0.5, 0.8))

# Set chart title and label axes
plt.title("Square Numbers", fontsize = 15)
plt.xlabel("Value", fontsize = 10)
plt.ylabel("Square of Value", fontsize = 10)

#The axis() function requires four values: the minimum and maximum values for the x-axis and the y-axis. 
plt.axis([0, 1100, 0, 1100000])

plt.show()

# %%
# Using a Colormap , you can choose different colormaps in Python 
# defining custom colors c = 'red' by using RGB color model 

import matplotlib.pyplot as plt

x_value = range(1,1100)
y_value = [x**2 for x in x_value]

plt.scatter(x_value, y_value, c=y_value, cmap=plt.cm.flag, edgecolor='none', s=40)

# Set chart title and label axes
plt.title("Square Numbers", fontsize = 15)
plt.xlabel("Value", fontsize = 10)
plt.ylabel("Square of Value", fontsize = 10)

#The axis() function requires four values: the minimum and maximum values for the x-axis and the y-axis. 
plt.axis([0, 1100, 0, 1100000])

plt.show()

# %%
# Saving your plots automatically 

import matplotlib.pyplot as plt

x_value = range(1,1100)
y_value = [x**2 for x in x_value]

plt.scatter(x_value, y_value, c=y_value, cmap=plt.cm.Reds, edgecolor='none', s=40)

# Set chart title and label axes
plt.title("Square Numbers", fontsize = 15)
plt.xlabel("Value", fontsize = 10)
plt.ylabel("Square of Value", fontsize = 10)

#The axis() function requires four values: the minimum and maximum values for the x-axis and the y-axis. 
plt.axis([0, 1100, 0, 1100000])

plt.show()

# %% [markdown]
# ### Random Walks

# %%
# Random Walks class

from random import choice 

class RandomWalk():
    """A class to generate random walks"""
    
    def __int__(self, num_points=5000):
        self.num_points = num_points
        
        # All walks start at (0, 0)
        self.x_values = [0]
        self.y_values = [0]
        
    def fill_walk(self):
        """Calculate all the points in the walk"""
        
        # Keep taking steps until the walk reaches the desired length
        while len(self.x_values) < self.num_points:
            
            # Decide which direction to go and how far to go in that direction
            # go to right or go to left, return 1 as turn to right, return -1 as turn to left
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance
            
            y_direction = choice ([1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance
            
            # Reject moves that go no where.
            if x_step == 0 and y_step == 0:
                continue 
            
            # Calculate the next x and y values.
            next_x = self.x_values[-1] + x_step
            next_y = self.y_values[-1] + y_step
            
            self.x_values.append(next_x)
            self.y_values.append(next_y)

import matplotlib.pyplot as plt
rw = RandomWalk()
rw.fill_walk()

plt.scatter(rw.x_values, rw.y_values, s=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-890df50d88c9> in <module>()
#      42 import matplotlib.pyplot as plt
#      43 rw = RandomWalk()
# ---> 44 rw.fill_walk()
#      45
#      46 plt.scatter(rw.x_values, rw.y_values, s=15)
#
# <ipython-input-69-890df50d88c9> in fill_walk(self)
#      17
#      18         # Keep taking steps until the walk reaches the desired length
# ---> 19         while len(self.x_values) < self.num_points:
#      20
#      21             # Decide which direction to go and how far to go in that direction
#
# AttributeError: 'RandomWalk' object has no attribute 'x_values'

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk 

rw = RandomWalk()
rw.fill_walk()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-64-7e2dddce0670> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 from random_walk import RandomWalk
#       3
#       4 rw = RandomWalk()
#       5 rw.fill_walk()
#
# ImportError: No module named 'random_walk'
